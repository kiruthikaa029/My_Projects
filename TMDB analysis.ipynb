# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import json
import seaborn as sb

# %%
df=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df[:10]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
df['genres'] = df['genres'].apply(lambda x: ', '.join([item['name'] for item in json.loads(x)]))
df['keywords'] = df['keywords'].apply(lambda x: ', '.join([item['name'] for item in json.loads(x)]))
df['production_companies'] = df['production_companies'].apply(lambda x: ', '.join([item['name'] for item in json.loads(x)]))
df['production_countries'] = df['production_countries'].apply(lambda x: ', '.join([item['name'] for item in json.loads(x)]))
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: ', '.join([item['name'] for item in json.loads(x)]))

# %%
df[:5]
# Out:
#       budget                                       genres  \
# 0  237000000  Action, Adventure, Fantasy, Science Fiction
# 1  300000000                   Adventure, Fantasy, Action
# 2  245000000                     Action, Adventure, Crime
# 3  250000000               Action, Crime, Drama, Thriller
# 4  260000000           Action, Adventure, Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash, future, space war, space colony...                en
# 1  ocean, drug abuse, exotic island, east india t...                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
                                              
     # TASK 1

# %%
df.shape
# Out:
# (4803, 20)

# %%
f = df[['title', 'genres']].head(50)
f
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %%
# Interpretation : The rows & col were found using shape . first 50 movie title were displayed using head ().

# %%
                # TASK 2

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df['runtime'].fillna(df['runtime'].mean(), inplace=True)

# %%
categorical_columns = ['homepage', 'overview', 'release_date', 'tagline']
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
#Interpretation :- The null values were replaced for num category with mean & categorical col with mode

# %%
# TASK 3

# %%
movies=df[df['budget'] > 220000]
category= movies['genres']
category
# Out:
# 0       Action, Adventure, Fantasy, Science Fiction
# 1                        Adventure, Fantasy, Action
# 2                          Action, Adventure, Crime
# 3                    Action, Crime, Drama, Thriller
# 4                Action, Adventure, Science Fiction
#                            ...
# 4680                        Crime, Horror, Thriller
# 4682                                         Horror
# 4720                                          Drama
# 4758                      Thriller, Science Fiction
# 4770                                  Drama, Comedy
# Name: genres, Length: 3684, dtype: object

# %%
# Interpretation :-  The genres which had budget above 220000 were found out using conditional statement.

# %%
# TASK 4

# %%
titles=df[df['revenue'] > 961000000]
rev_cat= movies['genres']
rev_cat
# Out:
# 0       Action, Adventure, Fantasy, Science Fiction
# 1                        Adventure, Fantasy, Action
# 2                          Action, Adventure, Crime
# 3                    Action, Crime, Drama, Thriller
# 4                Action, Adventure, Science Fiction
#                            ...
# 4680                        Crime, Horror, Thriller
# 4682                                         Horror
# 4720                                          Drama
# 4758                      Thriller, Science Fiction
# 4770                                  Drama, Comedy
# Name: genres, Length: 3684, dtype: object

# %%
# InterpretationThe genres with revenue greater than $961,000,000 were found out using conditional statements.

# %%
# TASK 5

# %%
df = df[(df['budget'] != 0) | (df['revenue'] != 0)]

# %%
#Interpretation :- In this method using conditional statement we are only fetching rows that have greater than 0 budget & revenue.

# %%
# TASK 6.1

# %%
mov_high_rev=df.sort_values(by='revenue',ascending=False).head(10)
print(mov_high_rev[['title','revenue']])
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
#Interpretation:- The top 10 movies were found and was sorted using sort_values , ascending.

# %%
# TASK 6.2

# %%
mov_low_budget=df.sort_values(by='budget',ascending=True).head(10)
print(mov_low_budget[['title','budget']])
# Out:
#                             title  budget
# 4247        Me You and Five Bucks       1
# 4251                Fetching Cody       1
# 4238                 Modern Times       1
# 4293                 The Algerian       1
# 4369                         Slam       1
# 4424                  Fear Clinic       1
# 4262        Incident at Loch Ness       1
# 4140  To Be Frank, Sinatra at 100       2
# 3967          Four Single Fathers       3
# 3687                  Without Men       4

# %%
#Interpretation:- Top 10 movies with least budget were found and was sorted using sort_values , ascending.

# %%
# TASK 7

# %%
new_df = df[['popularity', 'budget']]

corr_matrix = new_df.corr()
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
#Interpretation:- The popularity of movies are positively correlated.

# %%
#TASK 8

# %%
company_counts=df.groupby(['production_companies'])['title'].count().reset_index(name='count')

company_counts
# Out:
#                                    production_companies  count
# 0                                                           90
# 1     100 Bares, Haddock Films S.R.L., Instituto Nac...      1
# 2     100 Bares, Ministerio de Cultura, Instituto de...      1
# 3     1492 Pictures, Dune Entertainment, Fox 2000 Pi...      1
# 4             1492 Pictures, Heyday films, Warner Bros.      2
# ...                                                 ...    ...
# 3044  Zentropa Entertainments, Det Danske Filminstit...      1
# 3045  Zentropa Entertainments, Det Danske Filminstit...      1
# 3046  Zininsa Film Production, Intellectual Properti...      1
# 3047                                         area japan      1
# 3048                                               icon      1
#
# [3049 rows x 2 columns]

# %%
#Interpretation:- Production companies with their counts were found.

# %%
# TASK 9

# %%
top25= company_counts.sort_values(by='count',ascending = False).head(25)
top25
# Out:
#                                    production_companies  count
# 0                                                           90
# 1676                                 Paramount Pictures     52
# 2600                                 Universal Pictures     40
# 332                                   Columbia Pictures     34
# 1486                                    New Line Cinema     30
# 1369                          Metro-Goldwyn-Mayer (MGM)     28
# 2411             Twentieth Century Fox Film Corporation     27
# 2953                                       Warner Bros.     24
# 2886                               Walt Disney Pictures     21
# 2354                                Touchstone Pictures     18
# 333                       Columbia Pictures Corporation     15
# 607                                     Dimension Films     15
# 639                                DreamWorks Animation     12
# 1397                                      Miramax Films     11
# ...

# %%
# TASK 10

# %%
top_500 = df.sort_values(by='revenue', ascending=False).head(500)

# %%
plt.figure(figsize=(12,3))
plt.subplot(131)
sb.boxplot(x='budget', data=top_500)
plt.title('Box Plot for Budget')
plt.subplot(132)
sb.boxplot(x='revenue', data=df)
plt.title('Box Plot for revenue')
plt.subplot(133)
sb.boxplot(x='runtime', data=df)
plt.title('Box Plot for runtime')
plt.show()

# %%
# TASK 11

# %%
average_runtime = top_500['runtime'].mean()

# Filter the DataFrame to select movies with runtimes above the average
above_average_movies = top_500[top_500['runtime'] > average_runtime]

# Display the names of the movies and their runtimes
movie_names_runtimes = above_average_movies[['title', 'runtime']]
print(movie_names_runtimes)
# Out:
#                  title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 521       The Terminal    128.0
# 397   It's Complicated    121.0
# 1744        Knocked Up    129.0
# 717       Jack Reacher    130.0
# 714         Collateral    120.0
#
# [234 rows x 2 columns]

# %%
# Interpretation :-avg runtime was found & rows having movies greater than avg runtime were filtered.
